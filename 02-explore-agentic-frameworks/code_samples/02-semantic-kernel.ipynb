# %% [markdown]
# # Semantic Kernel
#
# In this code sample, you will use the [Semantic Kernel](https://aka.ms/ai-agents-beginners/semantic-kernel) AI Framework to create a simple agent.
#
# The purpose of this sample is to demonstrate the steps that will later be applied in additional code samples when implementing various agentic patterns.

# %% [markdown]
# # Install package

# %%
# %pip install semantic-kernel openai python-dotenv
# Out:
# Collecting semantic-kernel
#   Downloading semantic_kernel-1.41.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: openai in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (2.32.0)
# Requirement already satisfied: python-dotenv in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (1.2.2)
# Collecting azure-ai-projects~=1.0.0b12 (from semantic-kernel)
#   Downloading azure_ai_projects-1.0.0-py3-none-any.whl.metadata (21 kB)
# Collecting azure-ai-agents>=1.2.0b3 (from semantic-kernel)
#   Downloading azure_ai_agents-1.2.0b6-py3-none-any.whl.metadata (74 kB)
# Requirement already satisfied: aiohttp~=3.8 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from semantic-kernel) (3.13.5)
# Collecting cloudevents~=1.0 (from semantic-kernel)
#   Downloading cloudevents-1.12.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.13,>=2.0 (from semantic-kernel)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Requirement already satisfied: pydantic-settings~=2.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from semantic-kernel) (2.14.0)
# Collecting defusedxml~=0.7 (from semantic-kernel)
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: azure-identity>=1.13 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from semantic-kernel) (1.25.3)
# Requirement already satisfied: numpy>=1.26.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from semantic-kernel) (2.4.4)
# Collecting openapi_core<0.20,>=0.18 (from semantic-kernel)
#   Downloading openapi_core-0.19.5-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: websockets<16,>=13 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from semantic-kernel) (15.0.1)
# Collecting aiortc>=1.9.0 (from semantic-kernel)
#   Downloading aiortc-1.14.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: opentelemetry-api~=1.24 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from semantic-kernel) (1.41.0)
# Requirement already satisfied: opentelemetry-sdk~=1.24 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from semantic-kernel) (1.41.0)
# Collecting prance<25.4.9,>=23.6.21 (from semantic-kernel)
#   Downloading prance-25.4.8.0-py3-none-any.whl.metadata (13 kB)
# Collecting pybars4~=0.9 (from semantic-kernel)
#   Downloading pybars4-0.9.13.tar.gz (29 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: jinja2~=3.1 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from semantic-kernel) (3.1.6)
# Requirement already satisfied: nest-asyncio~=1.6 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from semantic-kernel) (1.6.0)
# Collecting scipy>=1.15.1 (from semantic-kernel)
#   Downloading scipy-1.17.1-cp312-cp312-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: typing-extensions>=4.13 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from semantic-kernel) (4.15.0)
# Requirement already satisfied: mcp>=1.26.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from semantic-kernel) (1.27.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from aiohttp~=3.8->semantic-kernel) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from aiohttp~=3.8->semantic-kernel) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from aiohttp~=3.8->semantic-kernel) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from aiohttp~=3.8->semantic-kernel) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from aiohttp~=3.8->semantic-kernel) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from aiohttp~=3.8->semantic-kernel) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from aiohttp~=3.8->semantic-kernel) (1.23.0)
# Requirement already satisfied: isodate>=0.6.1 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from azure-ai-projects~=1.0.0b12->semantic-kernel) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from azure-ai-projects~=1.0.0b12->semantic-kernel) (1.39.0)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from azure-ai-projects~=1.0.0b12->semantic-kernel) (12.28.0)
# Collecting deprecation<3.0,>=2.0 (from cloudevents~=1.0->semantic-kernel)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: packaging in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from deprecation<3.0,>=2.0->cloudevents~=1.0->semantic-kernel) (26.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from jinja2~=3.1->semantic-kernel) (3.0.3)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (4.26.0)
# Collecting jsonschema-path<0.4.0,>=0.3.1 (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading jsonschema_path-0.3.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting more-itertools (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading more_itertools-11.0.2-py3-none-any.whl.metadata (41 kB)
# Collecting openapi-schema-validator<0.7.0,>=0.6.0 (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading openapi_schema_validator-0.6.3-py3-none-any.whl.metadata (5.4 kB)
# Collecting openapi-spec-validator<0.8.0,>=0.7.1 (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading openapi_spec_validator-0.7.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting parse (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading parse-1.21.1-py2.py3-none-any.whl.metadata (21 kB)
# Collecting werkzeug<3.1.2 (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading werkzeug-3.1.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.30.0)
# Requirement already satisfied: PyYAML>=5.1 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (6.0.3)
# Collecting pathable<0.5.0,>=0.4.1 (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading pathable-0.4.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting referencing>=0.28.4 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading referencing-0.36.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (2.33.1)
# Collecting rfc3339-validator (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel)
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting lazy-object-proxy<2.0.0,>=1.7.1 (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading lazy_object_proxy-1.12.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from opentelemetry-api~=1.24->semantic-kernel) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.24->semantic-kernel) (3.23.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.62b0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from opentelemetry-sdk~=1.24->semantic-kernel) (0.62b0)
# Collecting chardet>=5.2 (from prance<25.4.9,>=23.6.21->semantic-kernel)
#   Downloading chardet-7.4.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.4 kB)
# Collecting ruamel.yaml>=0.18.10 (from prance<25.4.9,>=23.6.21->semantic-kernel)
#   Downloading ruamel_yaml-0.19.1-py3-none-any.whl.metadata (16 kB)
# Collecting PyMeta3>=0.5.1 (from pybars4~=0.9->semantic-kernel)
#   Downloading PyMeta3-0.5.1.tar.gz (29 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.13,>=2.0->semantic-kernel) (0.7.0)
# Collecting pydantic-core==2.41.5 (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.13,>=2.0->semantic-kernel)
#   Downloading pydantic_core-2.41.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.13,>=2.0->semantic-kernel) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (2026.4.22)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from openai) (0.14.0)
# Requirement already satisfied: sniffio in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from openai) (4.67.3)
# Requirement already satisfied: httpcore==1.* in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Collecting aioice<1.0.0,>=0.10.1 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading aioice-0.10.2-py3-none-any.whl.metadata (4.1 kB)
# Collecting av<17.0.0,>=14.0.0 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading av-16.1.0-cp312-cp312-macosx_14_0_arm64.whl.metadata (4.6 kB)
# Requirement already satisfied: cryptography>=44.0.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic-kernel) (46.0.7)
# Collecting google-crc32c>=1.1 (from aiortc>=1.9.0->semantic-kernel)
#   Using cached google_crc32c-1.8.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (1.7 kB)
# Collecting pyee>=13.0.0 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading pyee-13.0.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting pylibsrtp>=0.10.0 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading pylibsrtp-1.0.0-cp310-abi3-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Collecting pyopenssl>=25.0.0 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading pyopenssl-26.1.0-py3-none-any.whl.metadata (19 kB)
# Collecting dnspython>=2.0.0 (from aioice<1.0.0,>=0.10.1->aiortc>=1.9.0->semantic-kernel)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting ifaddr>=0.2.0 (from aioice<1.0.0,>=0.10.1->aiortc>=1.9.0->semantic-kernel)
#   Downloading ifaddr-0.2.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: msal>=1.35.1 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from azure-identity>=1.13->semantic-kernel) (1.36.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from azure-identity>=1.13->semantic-kernel) (1.3.1)
# Requirement already satisfied: cffi>=2.0.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from cryptography>=44.0.0->aiortc>=1.9.0->semantic-kernel) (2.0.0)
# Requirement already satisfied: pycparser in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=44.0.0->aiortc>=1.9.0->semantic-kernel) (3.0)
# Requirement already satisfied: httpx-sse>=0.4 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from mcp>=1.26.0->semantic-kernel) (0.4.3)
# Requirement already satisfied: pyjwt>=2.10.1 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.26.0->semantic-kernel) (2.12.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from mcp>=1.26.0->semantic-kernel) (0.0.26)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from mcp>=1.26.0->semantic-kernel) (3.3.4)
# Requirement already satisfied: starlette>=0.27 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from mcp>=1.26.0->semantic-kernel) (1.0.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from mcp>=1.26.0->semantic-kernel) (0.41.0)
# Requirement already satisfied: click>=7.0 in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from uvicorn>=0.31.1->mcp>=1.26.0->semantic-kernel) (8.3.3)
# Requirement already satisfied: six in /Users/nphoang/CodeSpace/HCMUS/TN/learn-ai-agents-by-microsoft/.venv/lib/python3.12/site-packages (from rfc3339-validator->openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel) (1.17.0)
# Downloading semantic_kernel-1.41.3-py3-none-any.whl (924 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 924.3/924.3 kB 1.4 MB/s  0:00:00 eta 0:00:01
# Downloading azure_ai_projects-1.0.0-py3-none-any.whl (115 kB)
# Downloading cloudevents-1.12.1-py3-none-any.whl (55 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading openapi_core-0.19.5-py3-none-any.whl (106 kB)
# Downloading jsonschema_path-0.3.4-py3-none-any.whl (14 kB)
# Downloading openapi_schema_validator-0.6.3-py3-none-any.whl (8.8 kB)
# Downloading openapi_spec_validator-0.7.2-py3-none-any.whl (39 kB)
# Downloading lazy_object_proxy-1.12.0-cp312-cp312-macosx_11_0_arm64.whl (26 kB)
# Downloading pathable-0.4.4-py3-none-any.whl (9.6 kB)
# Downloading prance-25.4.8.0-py3-none-any.whl (36 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp312-cp312-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 609.5 kB/s  0:00:02 eta 0:00:01
# Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Downloading werkzeug-3.1.1-py3-none-any.whl (224 kB)
# Downloading aiortc-1.14.0-py3-none-any.whl (93 kB)
# Downloading aioice-0.10.2-py3-none-any.whl (24 kB)
# Downloading av-16.1.0-cp312-cp312-macosx_14_0_arm64.whl (21.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 924.3 kB/s  0:00:23m0:00:0100:01
# Downloading azure_ai_agents-1.2.0b6-py3-none-any.whl (217 kB)
# Downloading chardet-7.4.3-cp312-cp312-macosx_11_0_arm64.whl (854 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 854.9/854.9 kB 383.4 kB/s  0:00:02eta 0:00:01
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
# Using cached google_crc32c-1.8.0-cp312-cp312-macosx_12_0_arm64.whl (31 kB)
# Downloading ifaddr-0.2.0-py3-none-any.whl (12 kB)
# Downloading pyee-13.0.1-py3-none-any.whl (15 kB)
# Downloading pylibsrtp-1.0.0-cp310-abi3-macosx_11_0_arm64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 784.8 kB/s  0:00:02 eta 0:00:01
# Downloading pyopenssl-26.1.0-py3-none-any.whl (58 kB)
# Downloading ruamel_yaml-0.19.1-py3-none-any.whl (118 kB)
# Downloading scipy-1.17.1-cp312-cp312-macosx_14_0_arm64.whl (20.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 776.7 kB/s  0:00:26m0:00:0100:01
# Downloading more_itertools-11.0.2-py3-none-any.whl (71 kB)
# Downloading parse-1.21.1-py2.py3-none-any.whl (19 kB)
# Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Building wheels for collected packages: pybars4, PyMeta3
#   Building wheel for pybars4 (pyproject.toml) ... done
#   Created wheel for pybars4: filename=pybars4-0.9.13-py3-none-any.whl size=14420 sha256=eea80344e6bbc63b2a45caae78c8eb26d39e1ae3271c423f4517eea9397f7b9b
#   Stored in directory: /Users/nphoang/Library/Caches/pip/wheels/75/2d/da/c75b2fc7b00dc9c154dff65f689a318e7d24b44c612c2b21f1
#   Building wheel for PyMeta3 (pyproject.toml) ... done
#   Created wheel for PyMeta3: filename=pymeta3-0.5.1-py3-none-any.whl size=16517 sha256=c9529c1d906e4c3ca48f07214296a2b807e246ea367756b5ff08ff3cbb2a0022
#   Stored in directory: /Users/nphoang/Library/Caches/pip/wheels/5a/9b/2c/81b7551d2c05a482817e6c3b3d2f8ad2a0229db874c4bc6346
# Successfully built pybars4 PyMeta3
# Installing collected packages: PyMeta3, parse, ifaddr, werkzeug, scipy, ruamel.yaml, rfc3339-validator, referencing, pyee, pydantic-core, pybars4, pathable, more-itertools, lazy-object-proxy, google-crc32c, dnspython, deprecation, defusedxml, chardet, av, pylibsrtp, pydantic, prance, jsonschema-path, cloudevents, aioice, pyopenssl, azure-ai-agents, openapi-schema-validator, azure-ai-projects, aiortc, openapi-spec-validator, openapi_core, semantic-kernel
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 3.1.8
#     Uninstalling Werkzeug-3.1.8:
#       Successfully uninstalled Werkzeug-3.1.8
#   Attempting uninstall: referencing━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/34 [scipy]
#     Found existing installation: referencing 0.37.0━━━━━━━━━━━  4/34 [scipy]
#     Uninstalling referencing-0.37.0:━━━━━━━━━━━━━━━━━━━━━━━━━━  4/34 [scipy]
#       Successfully uninstalled referencing-0.37.0━━━━━━━━━━━━━  4/34 [scipy]
#   Attempting uninstall: pydantic-core━━━━━━━━━━━━━━━━━━━━━━━━━  4/34 [scipy]
#     Found existing installation: pydantic_core 2.46.3━━━━━━━━━  4/34 [scipy]
#     Uninstalling pydantic_core-2.46.3:━━━━━━━━━━━━━━━━━━━━━━━━  4/34 [scipy]
#       Successfully uninstalled pydantic_core-2.46.3━━━━━━━━━━━  4/34 [scipy]
#   Attempting uninstall: pydantic0m╺━━━━━━━━━━━━━━━━━ 19/34 [av]e-itertools]
#     Found existing installation: pydantic 2.13.3━━━━━━━━━━━━━━ 19/34 [av]
#     Uninstalling pydantic-2.13.3:0m╺━━━━━━━━━━━━━━━━━ 19/34 [av]
#       Successfully uninstalled pydantic-2.13.3━━━━━━━━━━━━━━━━ 19/34 [av]
#   Attempting uninstall: azure-ai-projectsm╸━━━━━━━━━ 26/34 [pyopenssl]
#     Found existing installation: azure-ai-projects 2.1.0━━━━━━ 26/34 [pyopenssl]
#     Uninstalling azure-ai-projects-2.1.0:1m╸━━━━━━━━━ 26/34 [pyopenssl]
#       Successfully uninstalled azure-ai-projects-2.1.0━━━━━━━━ 26/34 [pyopenssl]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34/34 [semantic-kernel] [semantic-kernel]s]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# agent-framework-foundry 1.1.0 requires azure-ai-projects<3.0,>=2.1.0, but you have azure-ai-projects 1.0.0 which is incompatible.
# azure-functions 1.24.0 requires werkzeug~=3.1.3; python_version >= "3.9", but you have werkzeug 3.1.1 which is incompatible.
# Successfully installed PyMeta3-0.5.1 aioice-0.10.2 aiortc-1.14.0 av-16.1.0 azure-ai-agents-1.2.0b6 azure-ai-projects-1.0.0 chardet-7.4.3 cloudevents-1.12.1 defusedxml-0.7.1 deprecation-2.1.0 dnspython-2.8.0 google-crc32c-1.8.0 ifaddr-0.2.0 jsonschema-path-0.3.4 lazy-object-proxy-1.12.0 more-itertools-11.0.2 openapi-schema-validator-0.6.3 openapi-spec-validator-0.7.2 openapi_core-0.19.5 parse-1.21.1 pathable-0.4.4 prance-25.4.8.0 pybars4-0.9.13 pydantic-2.12.5 pydantic-core-2.41.5 pyee-13.0.1 pylibsrtp-1.0.0 pyopenssl-26.1.0 referencing-0.36.2 rfc3339-validator-0.1.4 ruamel.yaml-0.19.1 scipy-1.17.1 semantic-kernel-1.41.3 werkzeug-3.1.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import the Needed Python Packages

# %%
import json
import os 

from typing import Annotated

from dotenv import load_dotenv

from IPython.display import display, HTML

from openai import AsyncOpenAI

from semantic_kernel.agents import ChatCompletionAgent, ChatHistoryAgentThread
from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion
from semantic_kernel.contents import FunctionCallContent, FunctionResultContent, StreamingTextContent
from semantic_kernel.functions import kernel_function

# %% [markdown]
# ## Creating the Client
#
# In this example, we will use [GitHub Models](https://aka.ms/ai-agents-beginners/github-models) to access the LLM.
#
# The `ai_model_id` is set to `gpt-4o-mini`. Try switching the model to another one available in the GitHub Models marketplace to observe different results.
#
# To use the `Azure Inference SDK` required for the `base_url` for GitHub Models, we will utilize the `OpenAIChatCompletion` connector within Semantic Kernel. There are also other [available connectors](https://learn.microsoft.com/semantic-kernel/concepts/ai-services/chat-completion) that allow you to use Semantic Kernel with other model providers.

# %%
import random   

# Define a sample plugin for the sample

class DestinationsPlugin:
    """A List of Random Destinations for a vacation."""

    def __init__(self):
        # List of vacation destinations
        self.destinations = [
            "Barcelona, Spain",
            "Paris, France",
            "Berlin, Germany",
            "Tokyo, Japan",
            "Sydney, Australia",
            "New York, USA",
            "Cairo, Egypt",
            "Cape Town, South Africa",
            "Rio de Janeiro, Brazil",
            "Bali, Indonesia"
        ]
        # Track last destination to avoid repeats
        self.last_destination = None

    @kernel_function(description="Provides a random vacation destination.")
    def get_random_destination(self) -> Annotated[str, "Returns a random vacation destination."]:
        # Get available destinations (excluding last one if possible)
        available_destinations = self.destinations.copy()
        if self.last_destination and len(available_destinations) > 1:
            available_destinations.remove(self.last_destination)

        # Select a random destination
        destination = random.choice(available_destinations)

        # Update the last destination
        self.last_destination = destination

        return destination

# %%
load_dotenv()
client = AsyncOpenAI(
    api_key=os.environ.get("GITHUB_TOKEN"), 
    base_url="https://models.inference.ai.azure.com/",
)

# Create an AI Service that will be used by the `ChatCompletionAgent`
chat_completion_service = OpenAIChatCompletion(
    ai_model_id="gpt-4o-mini",
    async_client=client,
)

# %% [markdown]
# ## Creating the Agent
#
# Here, we create the Agent named `TravelAgent`.
#
# In this example, we use very basic instructions. Feel free to modify these instructions to observe how the agent's behavior changes.

# %%
agent = ChatCompletionAgent(
    service=chat_completion_service, 
    plugins=[DestinationsPlugin()],
    name="TravelAgent",
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations",
)

# %% [markdown]
# ## Running the Agents
#
# Now we can execute the Agent by setting up the `ChatHistory` and including the `system_message` within it. We'll use the `AGENT_INSTRUCTIONS` that we established earlier.
#
# Once these are set up, we create `user_inputs`, which represent what the user is sending to the agent. In this example, the message is set to `Plan me a sunny vacation`.
#
# You can modify this message to observe how the agent reacts differently.

# %%
user_inputs = [
    "Plan me a day trip.",
    "I don't like that destination. Plan me another vacation.",
]

async def main():
    thread: ChatHistoryAgentThread | None = None

    for user_input in user_inputs:
        html_output = (
            f"<div style='margin-bottom:10px'>"
            f"<div style='font-weight:bold'>User:</div>"
            f"<div style='margin-left:20px'>{user_input}</div></div>"
        )

        agent_name = None
        full_response: list[str] = []
        function_calls: list[str] = []

        # Buffer to reconstruct streaming function call
        current_function_name = None
        argument_buffer = ""

        async for response in agent.invoke_stream(
            messages=user_input,
            thread=thread,
        ):
            thread = response.thread
            agent_name = response.name
            content_items = list(response.items)

            for item in content_items:
                if isinstance(item, FunctionCallContent):
                    if item.function_name:
                        current_function_name = item.function_name

                    # Accumulate arguments (streamed in chunks)
                    if isinstance(item.arguments, str):
                        argument_buffer += item.arguments
                elif isinstance(item, FunctionResultContent):
                    # Finalize any pending function call before showing result
                    if current_function_name:
                        formatted_args = argument_buffer.strip()
                        try:
                            parsed_args = json.loads(formatted_args)
                            formatted_args = json.dumps(parsed_args)
                        except Exception:
                            pass  # leave as raw string

                        function_calls.append(f"Calling function: {current_function_name}({formatted_args})")
                        current_function_name = None
                        argument_buffer = ""

                    function_calls.append(f"\nFunction Result:\n\n{item.result}")
                elif isinstance(item, StreamingTextContent) and item.text:
                    full_response.append(item.text)

        if function_calls:
            html_output += (
                "<div style='margin-bottom:10px'>"
                "<details>"
                "<summary style='cursor:pointer; font-weight:bold; color:#0066cc;'>Function Calls (click to expand)</summary>"
                "<div style='margin:10px; padding:10px; background-color:#f8f8f8; "
                "border:1px solid #ddd; border-radius:4px; white-space:pre-wrap; font-size:14px; color:#333;'>"
                f"{chr(10).join(function_calls)}"
                "</div></details></div>"
            )

        html_output += (
            "<div style='margin-bottom:20px'>"
            f"<div style='font-weight:bold'>{agent_name or 'Assistant'}:</div>"
            f"<div style='margin-left:20px; white-space:pre-wrap'>{''.join(full_response)}</div></div><hr>"
        )

        display(HTML(html_output))

await main()
# Out:
# <div style='margin-bottom:10px'><div style='font-weight:bold'>User:</div><div style='margin-left:20px'>Plan me a day trip.</div></div><div style='margin-bottom:20px'><div style='font-weight:bold'>TravelAgent:</div><div style='margin-left:20px; white-space:pre-wrap'>How about a day trip to Berlin, Germany? Here’s a suggested itinerary to make the most of your day:
#
# ### Morning
# - **Breakfast at a local café**: Start your day with a traditional German breakfast at a café. Try some fresh bread rolls with butter, jam, and a side of coffee.
# - **Visit the Brandenburg Gate**: One of Berlin's most famous landmarks, perfect for iconic photos.
#
# ### Midday
# - **Explore Museum Island**: A UNESCO World Heritage site that holds several important museums, such as the Pergamon Museum and the Berlin Cathedral. You can choose one or two museums to explore based on your interests.
# - **Lunch in Mitte**: Enjoy lunch at a local restaurant or a street food market. Try some Currywurst or a Döner kebab, both popular local dishes.
#
# ### Afternoon
# - **Stroll through Tiergarten**: After lunch, take a leisurely walk in Berlin's largest park, Tiergarten. It’s a great place to relax and enjoy nature within the city.
# - **Visit the Berlin Wall Memorial**: Learn about Berlin's history and the impact of the wall by visiting this poignant site.
#
# ### Evening
# - **Dinner at a traditional German restaurant**: End your day with a hearty dinner. Consider trying dishes like Sauerbraten (pot roast) or Wienerschnitzel (breaded veal cutlet).
# - **Experience Berlin’s nightlife**: If you have energy left, explore the vibrant nightlife. Consider visiting a bar or a club in areas like Kreuzberg or Friedrichshain.
#
# ### Tips
# - Wear comfortable shoes as you'll be walking a lot.
# - Public transportation is a great way to get around the city efficiently.
#
# Enjoy your day trip to Berlin! If you need any additional information or adjustments, feel free to ask.</div></div><hr>
# <div style='margin-bottom:10px'><div style='font-weight:bold'>User:</div><div style='margin-left:20px'>I don't like that destination. Plan me another vacation.</div></div><div style='margin-bottom:20px'><div style='font-weight:bold'>TravelAgent:</div><div style='margin-left:20px; white-space:pre-wrap'>How about a day trip to Cape Town, South Africa? Here’s a suggested itinerary to help you make the most of your time there:
#
# ### Morning
# - **Breakfast at the V&A Waterfront**: Start your day at one of the many local cafés at the V&A Waterfront, enjoying stunning views of the harbor. Try a traditional South African dish or some fresh pastries.
# - **Table Mountain**: Take the cable car up to Table Mountain (weather permitting). The views of Cape Town and the surrounding ocean are breathtaking.
#
# ### Midday
# - **Explore Kirstenbosch National Botanical Garden**: After visiting Table Mountain, head to this beautiful botanical garden. Take a stroll through the diverse plant life and enjoy a picnic if the weather allows.
# - **Lunch at a local eatery**: Enjoy some local cuisine at a restaurant near the gardens. Look for dishes featuring fresh seafood or traditional starters like biltong.
#
# ### Afternoon
# - **Visit the District Six Museum**: Return to the city and learn about the fascinating history of District Six and its people.
# - **Walk along the Bo-Kaap**: Explore the colorful streets of the Bo-Kaap neighborhood, known for its vibrant houses and rich Cape Malay culture. Don't forget to take lots of photos!
#
# ### Evening
# - **Dinner at Camps Bay**: Head to Camps Bay for a sunset dinner with a view of the beach. Enjoy fresh seafood or a braai (South African barbecue) at one of the beachfront restaurants.
# - **Sunset and relax**: After dinner, take a stroll along the beach, enjoying the sunset over the Atlantic Ocean.
#
# ### Tips
# - Consider a guided tour for specific attractions if you want a more in-depth experience.
# - Empty your camera to capture all the stunning views!
#
# Enjoy your day trip to Cape Town! If you have any preferences or need further customization, feel free to ask!</div></div><hr>
